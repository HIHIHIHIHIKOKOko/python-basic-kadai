# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i = 1
x = 10
for value in array:
    print(f"{i} {value}")
    i = i + 1

y = 0
while y < 9 :
    print(f"{x} {array[y]}")
    y = y + 1
    x = x + 1
# Out:
# 1 水
# 2 金
# 3 地
# 4 火
# 5 木
# 6 土
# 7 天
# 8 海
# 9 冥
# 10 水
# 11 金
# 12 地
# 13 火
# 14 木
# 15 土
# 16 天
# 17 海
# 18 冥

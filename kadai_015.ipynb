# %%
class Human:
    def __init__(self,name,age):
        self.name = ""
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name,self.age)

user = Human("ryo",33)
user.printinfo()
# Out:
# ryo 33
